# %%
import pandas as pd

# %%
proveedores=pd.read_excel('Data/Proveedores.xlsx')

# %%
proveedores.head()
# Out:
#                                           nombre  localidad  provincia  \
# 0            MNCI (Mov. Nac. Campesino Indigena)   Paternal        NaN
# 1            MNCI (Mov. Nac. Campesino Indigena)     Varela        NaN
# 2       UTT (Unión de Trabajadores de la Tierra)        NaN        NaN
# 3                FRIGORIFICO COOPERATIVO BRAGADO        NaN        NaN
# 4  ASOCIACION DE PRODUCTORES PORCINOS DE NAVARRO        NaN        NaN
#
#    cuilCuit                          tagsRubro             numeroCuenta  \
# 0       NaN          Mermelada, Miel, Conserva                      NaN
# 1       NaN  Pollo, Huevo de campo, Hortalizas  01701322-40000005143034
# 2       NaN                         Hortalizas  01401574-03509050681504
# 3       NaN                       Carne Vacuna                      NaN
# 4       NaN                     Carne de Cerdo                      NaN
#
#   nombreContacto  apellidoContacto  telefonoContacto  informacionAdicional  \
# ...

# %%
proveedores.fillna(value='', inplace=True)

# %%
proveedores.head()
# Out:
#                                           nombre  localidad provincia  \
# 0            MNCI (Mov. Nac. Campesino Indigena)   Paternal
# 1            MNCI (Mov. Nac. Campesino Indigena)     Varela
# 2       UTT (Unión de Trabajadores de la Tierra)
# 3                FRIGORIFICO COOPERATIVO BRAGADO
# 4  ASOCIACION DE PRODUCTORES PORCINOS DE NAVARRO
#
#   cuilCuit                          tagsRubro             numeroCuenta  \
# 0                   Mermelada, Miel, Conserva
# 1           Pollo, Huevo de campo, Hortalizas  01701322-40000005143034
# 2                                  Hortalizas  01401574-03509050681504
# 3                                Carne Vacuna
# 4                              Carne de Cerdo
#
#   nombreContacto  apellidoContacto  telefonoContacto informacionAdicional mail
# 0          CAMILA                         1150168291
# 1        MERCEDES                         1566455096
# 2      JUAN PABLO                         1138671384
# ...

# %%
proveedores.to_json(path_or_buf='Data/proveedores.json', orient='records')
